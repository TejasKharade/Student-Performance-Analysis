# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("StudentsPerformance.csv")
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 999   female        group D                some college  free/reduced
# 1000  female        group B           bachelor's degree      standard
# 1001  female        group C                some college      standard
# 1002  female        group B             master's degree      standard
# 1003    male        group C                some college      standard
#
#      test preparation course  math score  physics score  chemistry score  \
# ...

# %% [markdown]
# # Data Exploration

# %%
df.shape
# Out:
# (1004, 10)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'physics score',
#        'chemistry score', 'random_noise', 'student_id'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                     float64
# physics score                  float64
# chemistry score                  int64
# random_noise                   float64
# student_id                      object
# dtype: object

# %%
df.describe(include='all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count      994           1004                        1004       989
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       514            321                         228       638
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  physics score  chemistry score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       994 non-null    object
#  1   race/ethnicity               1004 non-null   object
#  2   parental level of education  1004 non-null   object
#  3   lunch                        989 non-null    object
#  4   test preparation course      1004 non-null   object
#  5   math score                   979 non-null    float64
#  6   physics score                996 non-null    float64
#  7   chemistry score              1004 non-null   int64
#  8   random_noise                 1004 non-null   float64
#  9   student_id                   1004 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 78.6+ KB

# %% [markdown]
# # Data Cleaning

# %%
df.isna().sum()
# Out:
# gender                         10
# race/ethnicity                  0
# parental level of education     0
# lunch                          15
# test preparation course         0
# math score                     25
# physics score                   8
# chemistry score                 0
# random_noise                    0
# student_id                      0
# dtype: int64

# %%
df.dropna(subset=['gender'], inplace=True)

# %%
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 999   female        group D                some college  free/reduced
# 1000  female        group B           bachelor's degree      standard
# 1001  female        group C                some college      standard
# 1002  female        group B             master's degree      standard
# 1003    male        group C                some college      standard
#
#      test preparation course  math score  physics score  chemistry score  \
# ...

# %%
df['math score']=df['math score'].fillna(df['math score'].mean())
df['physics score']=df['physics score'].fillna(df['physics score'].mean())

# %%
df.isna().sum()
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                          14
# test preparation course         0
# math score                      0
# physics score                   0
# chemistry score                 0
# random_noise                    0
# student_id                      0
# dtype: int64

# %%
df['lunch']=df['lunch'].fillna('Unknown')

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# physics score                  0
# chemistry score                0
# random_noise                   0
# student_id                     0
# dtype: int64

# %% [markdown]
# Now no Null values are present in the dataframe

# %%
df=df.drop(['random_noise','student_id'], axis=1)

# %%
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 999   female        group D                some college  free/reduced
# 1000  female        group B           bachelor's degree      standard
# 1001  female        group C                some college      standard
# 1002  female        group B             master's degree      standard
# 1003    male        group C                some college      standard
#
#      test preparation course  math score  physics score  chemistry score
# ...

# %% [markdown]
# # Extracting Some Meaningful Insights

# %% [markdown]
# 1. Compare Score Distributions by Gender

# %%
sns.boxplot(x='gender',y='math score', data=df)
plt.grid(True)

#Comparison Between the math marks scored by male and female

# %%
sns.boxplot(x='gender',y='physics score', data=df)
plt.grid(True)

# %% [markdown]
# Can we simultaneously compare the marks of physics and maths????

# %% [markdown]
# 2. Impact of Lunch Type on Performance

# %%
sns.boxplot(x='lunch',y='math score',data=df)
plt.grid(True)

# %%
sns.boxplot(x='lunch',y='physics score',data=df)
plt.grid(True)

# %% [markdown]
# 3. Parental Education vs Student Performance
#
# Does having more educated parents help?

# %%
sns.boxplot(x='parental level of education', y='math score', data=df)
plt.grid(True)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, "bachelor's degree"),
#   Text(1, 0, 'some college'),
#   Text(2, 0, "master's degree"),
#   Text(3, 0, "associate's degree"),
#   Text(4, 0, 'high school'),
#   Text(5, 0, 'some high school')])

# %% [markdown]
# 4. Comparison between the marks of differnt subjects

# %%
plt.figure(figsize=(10,6))
sns.pairplot(df[['math score','physics score','chemistry score','gender']], hue='gender')

# %% [markdown]
# Simultaneously comparing the scores of each subject

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

sns.barplot(x='gender', y='math score', data=df, ax=axes[0])
axes[0].set_title("Math Score")

sns.barplot(x='gender', y='physics score', data=df, ax=axes[1])
axes[1].set_title("physics Score")

sns.barplot(x='gender', y='chemistry score', data=df, ax=axes[2])
axes[2].set_title("chemistry Score")
# Out:
# Text(0.5, 1.0, 'chemistry Score')

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

sns.barplot(x='test preparation course', y='math score', data=df, ax=axes[0])
axes[0].set_title("Math Score")

sns.barplot(x='test preparation course', y='physics score', data=df, ax=axes[1])
axes[1].set_title("physics Score")

sns.barplot(x='test preparation course', y='chemistry score', data=df, ax=axes[2])
axes[2].set_title("chemistry Score")

fig.suptitle('Score vs Test Preparation')
# Out:
# Text(0.5, 0.98, 'Score vs Test Preparation')

# %%
sns.scatterplot(x='math score',y='physics score',data=df, hue='gender')
# Out:
# <Axes: xlabel='math score', ylabel='physics score'>

# %%
sns.histplot(x='math score', bins=10, data=df, kde=True)
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
correlation = df.corr(numeric_only=True)
sns.heatmap(correlation,annot=True,fmt=".2f",cmap='coolwarm',linewidths=1)
plt.title("Correlation Heatmap of Different Sunjects")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Different Sunjects')
